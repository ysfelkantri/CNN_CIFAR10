# %%
# %matplotlib inline
import tensorflow as tf
import keras
import numpy as np
import matplotlib.pyplot as plt
import cv2
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.2.0-rc3
# 2.3.1

# %%
# GETTING DATA FROM CIFAR-10 DATASET
from keras.datasets import cifar10

(x_train1, y_train1), (x_test1, y_test1) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
# SHOW THE SHAPE OF OUR TEST AND TRAIN DATASET
print("Data Shapes")
print("Train",end = "");print(x_train1.shape,y_train1.shape)
print("Test",end = "");print(x_test1.shape,y_test1.shape)
# Out:
# Data Shapes
# Train(50000, 32, 32, 3) (50000, 1)
# Test(10000, 32, 32, 3) (10000, 1)

# %%
NUM_CLASSES = 10
imageDimesions = (32,32,3)

############################### DISPLAY SOME SAMPLES IMAGES  OF ALL THE CLASSES
code = {'plane':0, 'car':1, 'bird':2, 'cat':3, 'deer':4, 'dog':5, 'frog':6, 'horse':7, 'ship':8, 'truck':9}

############################### GET THE VALUE OF KEY FROM DICTIONNARY
def getcode (n):
    for i,j in code.items() :
        if j == n :
            return i

############################### DISPLAY 36 RANDOM IMAGES TO CHECK THE TRAIN DATASET 
plt.figure(figsize=(10,10))
for n, i in enumerate(list(np.random.randint(0,len(x_train1),36))) :
    plt.subplot(6,6,n+1)
    plt.imshow(x_train1[i])
    plt.axis('off')
    plt.title(getcode(y_train1[i]))

# %%
############################### CALCULATE NUMBER OF SAMPLES

num_of_samples = []
for x in range(0,10):
    num_of_samples.append((len(np.where(y_train1==x)[0])))

# %%
############################### DISPLAY A BAR CHART SHOWING NUMBER OF SAMPLES FOR EACH CATEGORY
print(num_of_samples)
plt.figure(figsize=(12, 4))
plt.bar(range(0, NUM_CLASSES), num_of_samples)
plt.title("Distribution of the training dataset")
plt.xlabel("Class number")
plt.ylabel("Number of images")
plt.show()
# Out:
# [5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000, 5000]

# %%
############################### PREPROCESSING THE IMAGES
from keras.utils import to_categorical

def preprocessing(img):
    img = (img/255)       # TO NORMALIZE VALUES BETWEEN 0 AND 1 INSTEAD OF 0 TO 255
    return img

# TO IRETATE AND PREPROCESS ALL IMAGES
x_train2=np.array(list(map(preprocessing,x_train1)))  
x_test2=np.array(list(map(preprocessing,x_test1)))

# CONVERT CATEGORICAL TO NUMERICAL DATA 
y_train2= to_categorical(y_train1,NUM_CLASSES)
y_test2 = to_categorical(y_test1,NUM_CLASSES)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten , Dense, Activation,Dropout
from keras.layers.advanced_activations import LeakyReLU
from keras.preprocessing.image import ImageDataGenerator

# %%
# BUILD CNN MODEL LAYERS 

def make_model():
    model = Sequential()  
    model.add(Conv2D(16, (3, 3), padding ='same', activation = 'relu',input_shape = (32, 32, 3)))
    model.add(Conv2D(32, (3, 3), padding ='same', activation = 'relu', input_shape = (32, 32, 3)))
    model.add(MaxPooling2D(pool_size = (2, 2), strides = None, padding = 'valid',data_format = None))
    model.add(Dropout(0.25))
    model.add(Conv2D(32, (3, 3), padding = 'same', activation = 'relu', input_shape = (32, 32, 3)))
    model.add(Conv2D(64, (3, 3), padding ='same', activation = 'relu', input_shape = (32, 32, 3)))
    model.add(MaxPooling2D(pool_size = (2, 2), strides = None, padding = 'valid',data_format = None))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(256, input_shape = (256, )))
    model.add(Dense(NUM_CLASSES))
    model.add(LeakyReLU(0.1))
    model.add(Activation('softmax'))  
    return model

# %%
INIT_LR = 3e-3  # initial learning rate
EPOCHS = 20

# %%
model = make_model()  # define our model
# prepare model for fitting (loss, optimizer, etc)
model.compile(
    loss='categorical_crossentropy',  # we train 10-way classification
    optimizer=keras.optimizers.adamax(lr=INIT_LR),  # for SGD
    metrics=['accuracy']  # report accuracy during training
)

# %%
# TRAIN THE MODEL 
model.fit(
    x_train2,y_train2, 
    epochs=EPOCHS,
    validation_data=(x_test2, y_test2),
    shuffle=True,
    verbose=1,
    initial_epoch= 0
)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 32s 647us/step - loss: 1.5138 - accuracy: 0.4525 - val_loss: 1.1669 - val_accuracy: 0.5861
# Epoch 2/20
# 50000/50000 [==============================] - 31s 629us/step - loss: 1.1021 - accuracy: 0.6103 - val_loss: 0.9544 - val_accuracy: 0.6682
# Epoch 3/20
# 50000/50000 [==============================] - 31s 624us/step - loss: 0.9450 - accuracy: 0.6689 - val_loss: 0.8779 - val_accuracy: 0.6919
# Epoch 4/20
# 50000/50000 [==============================] - 32s 633us/step - loss: 0.8504 - accuracy: 0.7024 - val_loss: 0.7958 - val_accuracy: 0.7228
# Epoch 5/20
# 50000/50000 [==============================] - 33s 652us/step - loss: 0.7952 - accuracy: 0.7247 - val_loss: 0.7710 - val_accuracy: 0.7284
# Epoch 6/20
# 50000/50000 [==============================] - 32s 632us/step - loss: 0.7463 - accuracy: 0.7413 - val_loss: 0.7377 - val_accuracy: 0.7448
# Epoch 7/20
# 50000/50000 [==============================] - 33s 661us/step - loss: 0.7092 - accuracy: 0.7546 - val_loss: 0.7251 - val_accuracy: 0.7475
# Epoch 8/20
# 50000/50000 [==============================] - 31s 629us/step - loss: 0.6787 - accuracy: 0.7651 - val_loss: 0.7014 - val_accuracy: 0.7559
# Epoch 9/20
# 50000/50000 [==============================] - 32s 631us/step - loss: 0.6495 - accuracy: 0.7734 - val_loss: 0.7219 - val_accuracy: 0.7552
# Epoch 10/20
# 50000/50000 [==============================] - 31s 629us/step - loss: 0.6266 - accuracy: 0.7811 - val_loss: 0.7137 - val_accuracy: 0.7586
# Epoch 11/20
# 50000/50000 [==============================] - 32s 632us/step - loss: 0.6123 - accuracy: 0.7842 - val_loss: 0.6953 - val_accuracy: 0.7622
# Epoch 12/20
# 50000/50000 [==============================] - 32s 633us/step - loss: 0.5914 - accuracy: 0.7916 - val_loss: 0.7234 - val_accuracy: 0.7577
# Epoch 13/20
# 50000/50000 [==============================] - 32s 637us/step - loss: 0.5865 - accuracy: 0.7949 - val_loss: 0.6911 - val_accuracy: 0.7697
# Epoch 14/20
# 50000/50000 [==============================] - 32s 648us/step - loss: 0.5652 - accuracy: 0.8020 - val_loss: 0.6732 - val_accuracy: 0.7746
# Epoch 15/20
# 50000/50000 [==============================] - 32s 634us/step - loss: 0.5557 - accuracy: 0.8035 - val_loss: 0.6830 - val_accuracy: 0.7712
# Epoch 16/20
# 50000/50000 [==============================] - 32s 632us/step - loss: 0.5419 - accuracy: 0.8090 - val_loss: 0.6801 - val_accuracy: 0.7713
# Epoch 17/20
# 50000/50000 [==============================] - 33s 667us/step - loss: 0.5317 - accuracy: 0.8132 - val_loss: 0.6871 - val_accuracy: 0.7716
# Epoch 18/20
# 50000/50000 [==============================] - 31s 619us/step - loss: 0.5230 - accuracy: 0.8176 - val_loss: 0.7114 - val_accuracy: 0.7671
# Epoch 19/20
# 50000/50000 [==============================] - 32s 637us/step - loss: 0.5107 - accuracy: 0.8188 - val_loss: 0.6926 - val_accuracy: 0.7706
# Epoch 20/20
# 50000/50000 [==============================] - 32s 641us/step - loss: 0.5082 - accuracy: 0.8203 - val_loss: 0.6898 - val_accuracy: 0.7752

# %%
# EVALUATE SOME RANDOM DATA AND SHOW BOTH THE Y AND Y'

y_pred_test = model.predict_proba(x_test2)
y_pred_test_classes = np.argmax(y_pred_test, axis=1)
y_pred_test_max_probas = np.max(y_pred_test, axis=1)

score =model.evaluate(x_test2,y_test2,verbose=0)
print('Test Score:',score[0])
print('Test Accuracy:',score[1])

cols = 8
rows = 2
fig = plt.figure(figsize=(2 * cols - 1, 3 * rows - 1))
for i in range(cols):
    for j in range(rows):
        random_index = np.random.randint(0, len(y_test1))
        ax = fig.add_subplot(rows, cols, i * rows + j + 1)
        ax.grid('off')
        ax.axis('off')
        ax.imshow(x_test1[random_index, :])
        pred_label =  getcode(y_pred_test_classes[random_index])
        pred_proba = y_pred_test_max_probas[random_index]
        true_label = getcode(y_test1[random_index, 0])
        ax.set_title("pred: {}\nscore: {:.3}\ntrue: {}".format(
               pred_label, pred_proba, true_label
        ))
plt.show()
# Out:
# Test Score: 0.6897583619594574
# Test Accuracy: 0.7752000093460083

# %%
# DISPLAY CONFUSION MATRIX 

yPred = model.predict_classes(x_test2)
yTest_original=np.argmax(y_test2,axis=1)

class_names = np.unique(y_test1)

from sklearn.metrics import confusion_matrix
from pandas import DataFrame 
from seaborn import heatmap

# COMPUTE CONFUSION MATRIX
cnf_matrix = confusion_matrix(y_true=yTest_original, y_pred=yPred, normalize='true')

# PLOT CONFUSION MATRIX
plot_parameters = DataFrame(cnf_matrix, index = code.keys() ,columns = code.keys())
plt.figure(figsize = (15,7))
heatmap(plot_parameters, annot=True)

# %%
model.save('last_model_trained_.h5')
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # New Section
